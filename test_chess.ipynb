// %% [markdown]
// # Chess-RL Polyglot Testing
// This notebook tests the basic C# engine logic alongside the Python AI brain.

// %%
import torch
import numpy as np
print(f"PyTorch version: {torch.__version__}")
print(f"NumPy version: {np.__version__}")

// %%
#!csharp
#r "./ChessRL.Engine/bin/Debug/net9.0/ChessRL.Engine.dll"
using ChessRL.Engine;

var board = new Board();
ulong hash = Zobrist.CalculateHash(board);
Console.WriteLine($"Initial Board Hash: {hash:X}");
